# %% [markdown]
# # DIPA Practical 1
# - Name : Aayush Shah
# > Roll Number : 19BCE245

# %% [markdown]
# - To write a computer program capable of reducing the number of intensity levels in an image from 256 to 2, in integer powers of  2. The desired number of intensity levels needs to be a variable input.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("abc.png", cv2.IMREAD_GRAYSCALE)

# %%
image
# Out:
# array([[156, 164, 156, ..., 164, 156, 132],
#        [164, 164, 164, ..., 172, 156, 124],
#        [164, 156, 164, ..., 164, 156, 132],
#        ...,
#        [ 44,  44,  52, ..., 108, 100, 100],
#        [ 44,  44,  60, ..., 100, 108, 108],
#        [ 44,  44,  52, ..., 108, 100, 108]], dtype=uint8)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7662495B90>

# %%
row = 0
col = 0
level = 4
levels = 255/level-1
range = 255/level
_2_bit = []
for i in image:
    temp=[]
    for j in i:
        if j>range:
            temp.append(255)
        else:
            temp.append(0)
    _2_bit.append(temp)

# %%
_2_bit=np.asarray(_2_bit)
_2_bit.shape
# Out:
# (512, 512)

# %%
_2_bit
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255],
#        [  0,   0,   0, ..., 255, 255, 255]])

# %%
cv2_imshow(_2_bit)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7662426050>

# %%
def image_level(level,img):
  temp = []
  x = 255/level
  y = 255/(level-1)
  for i in img:
    temp1 = []
    for j in i:
      temp2 = []
      arr = np.arange(start=1, stop=level+1)
      for k in  arr:
        #print(k)
        if j <= x*k :
          temp1.append(y*k - y)
          break
    temp.append(temp1)
  return temp

# %%
for i in [2, 4 , 8, 16, 32, 64, 128]:
  t = image_level(i, image)
  a = np.array(t)
  cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7660183910>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7660180B10>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7660180B10>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7660BE6490>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7674F8D910>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7674AE3E10>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7674794C50>
